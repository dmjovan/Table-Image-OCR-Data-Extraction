# %% [markdown]
# ## Importing necessary libraries

# %%
from __future__ import print_function
from pylab import *

# %matplotlib inline

import os

import skimage 
from skimage import img_as_float, io
from skimage.color import rgb2gray
from skimage.filters import threshold_otsu
from skimage.morphology import binary_dilation, binary_erosion, disk, square
from skimage.draw import line
from skimage.transform import hough_line, hough_line_peaks

import numpy as np
import pandas as pd

import scipy 
from scipy import ndimage

import pytesseract
from pytesseract import pytesseract
pytesseract.tesseract_cmd = r'C:\Users\Jovan Dmitrovic\AppData\Local\Programs\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# ## Dictionary for PyTesseract Languages

# %%
tesseract_langs = { 'serbian_cirilic': 'srp',
                    'serbian_latin': 'srp_latn',
                    'italian': 'ita',
                    'french': 'fra',
                    'german': 'deu',
                    'english': 'eng'}

# %% [markdown]
# ##  Skimage - Image preproccesing

# %%
# image name should be set as language of table written
img_name = 'serbian_latin' 

# raise error if language is not suported
if img_name not in tesseract_langs.keys():
    raise Exception('Not supported language')
    
if not os.path.isdir('extracted_fields/'+img_name):
    os.makedirs('extracted_fields/'+img_name)
    
if not os.path.isdir('results/'+img_name):
    os.makedirs('results/'+img_name)

img_ext = '.jpg'
img = io.imread('input_images/' + img_name + img_ext)

M,N,D = shape(img)
print('Image dimensions : (%d, %d, %d)' %(M,N,D) )
print('Max image value : ' + str(img.flatten().max()))

img = img/255.0

img_gray = rgb2gray(img)

fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (12, 12), dpi = 120)

ax[0].imshow(img, cmap='jet',  vmin = 0, vmax = 1);
ax[0].set_title('Input image')
ax[0].set_axis_off()

ax[1].imshow(img_gray, cmap='gray', vmin = 0, vmax = 1);
ax[1].set_title('Input image - Grayscale')
ax[1].set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# Image dimensions : (705, 3848, 3)
# Max image value : 209

# %% [markdown]
# ## Image Otsu thresholding

# %%
t_otsu = threshold_otsu(img_gray)
img_otsu = img_gray < t_otsu

figure(figsize = (12, 12), dpi = 120);
imshow(img_otsu, cmap='gray',  vmin = 0, vmax = 1);
plt.title('Otsu thresholded image')
plt.axis('off')
plt.show();

# %% [markdown]
# ## Extraction of vertical and horizonatal table lines

# %% [markdown]
# ### Morphological operations

# %%
kernel_len = N//15
kernel_for_horiz = 1/kernel_len * np.ones((1, kernel_len))
kernel_for_vert = 1/kernel_len * np.ones((kernel_len, 1))

img_horizontals = ndimage.correlate(img_otsu, kernel_for_horiz)
img_horizontals = binary_dilation(img_horizontals, disk(radius=5))
horizontal_lines = binary_erosion(img_horizontals, disk(radius = 3))

img_verticals = ndimage.correlate(img_otsu, kernel_for_vert)
img_verticals = binary_dilation(img_verticals, disk(radius=5))
vertical_lines = binary_erosion(img_verticals, disk(radius = 3))

table_lines = horizontal_lines + vertical_lines
data = img_otsu*(~(table_lines))

# %% [markdown]
# ### Plotting extracted lines using morphological operations

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (12, 4), dpi = 120)
ax = axes.ravel()

ax[0].imshow(horizontal_lines, cmap='gray',  vmin = 0, vmax = 1);
ax[0].set_title('Extracted horizontal table lines')
ax[0].set_axis_off()

ax[1].imshow(vertical_lines, cmap='gray', vmin = 0, vmax = 1);
ax[1].set_title('Extracted vertical table lines')
ax[1].set_axis_off()

ax[2].imshow(table_lines, cmap='gray', vmin = 0, vmax = 1);
ax[2].set_title('Extracted table lines')
ax[2].set_axis_off()

ax[3].imshow(data, cmap='gray', vmin = 0, vmax = 1);
ax[3].set_title('Extracted data from table')
ax[3].set_axis_off()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Improved extraction of horizontal table lines using Hough transformation

# %%
hspace, angles, distances = hough_line(horizontal_lines)
_, angles_hor, dists_hor = hough_line_peaks(hspace, angles, distances)

num_horizontals = len(angles_hor)
print('Number of extracted horizontal lines: %d \n' %(num_horizontals))

img_hor = np.zeros((M, N))

for i in range(len(angles_hor)):
    theta = angles_hor[i]
    rho = dists_hor[i]
    
    img_one_hor_line_extracted = np.zeros((M,N))

    a = np.cos(theta)
    b = np.sin(theta)

    x0 = a*rho
    y0 = b*rho

    x1 = int(x0 + 3000*(-b))
    y1 = int(y0 + 3000*(a))
    x2 = int(x0 - 3000*(-b))
    y2 = int(y0 - 3000*(a))

    rr, cc = line(y1, x1, y2, x2)

    img_one_hor_line_extracted[rr, cc] = 1
    img_one_hor_line_extracted = binary_dilation(img_one_hor_line_extracted, disk(radius=5))
    img_hor += img_one_hor_line_extracted

figure(figsize = (12, 12), dpi = 120);
imshow(img_hor, cmap='gray',  vmin = 0, vmax = 1)
plt.title('Improved extraction of horizontal table lines using Hough transformation')
plt.axis('off')
plt.show()
# Out:
# Number of extracted horizontal lines: 6

# %% [markdown]
# ## Improved extraction of vertical table lines using Hough transformation

# %%
hspace, angles, distances = hough_line(vertical_lines)                                             
_, angles_ver, dists_ver = hough_line_peaks(hspace, angles, distances)

num_verticals = len(angles_ver)
print('Number of extracted vertical lines: %d \n' %(num_verticals))

img_ver = np.zeros((M,N))

for i in range(len(angles_ver)):
    theta = angles_ver[i]
    rho = dists_ver[i]

    img_one_ver_line_extracted = np.zeros((M,N))

    a = np.cos(theta)
    b = np.sin(theta)

    x0 = a*rho
    y0 = b*rho

    x1 = int(x0 + 500*(-b))
    y1 = int(y0 + 500*(a))
    x2 = int(x0 - 500*(-b))
    y2 = int(y0 - 500*(a))

    rr, cc = line(y1, x1, y2, x2)

    img_one_ver_line_extracted[rr, cc] = 1
    img_one_ver_line_extracted = binary_dilation(img_one_ver_line_extracted, disk(radius=5))
    img_ver += img_one_ver_line_extracted

figure(figsize = (12, 12), dpi = 120);
imshow(img_ver, cmap='gray',  vmin = 0, vmax = 1)
plt.title('Improved extraction of vertical table lines using Hough transformation')
plt.axis('off')
plt.show()
# Out:
# Number of extracted vertical lines: 6

# %% [markdown]
# ## Final extraction of table lines, table data and box corners

# %%
final_extracted_lines = (img_hor+img_ver)*img_otsu
final_extracted_corners = (img_hor*img_ver)*img_otsu

kernel_len = 3
kernel = (1/(kernel_len**2))*np.ones((kernel_len, kernel_len))

final_extracted_corners = skimage.filters.median(final_extracted_corners, kernel)
final_extracted_corners[final_extracted_corners>0] = 1

final_data = img_otsu*(1-final_extracted_lines)

figure(figsize = (12, 12), dpi = 120);
imshow(final_extracted_lines, cmap='gray',  vmin = 0, vmax = 1)
plt.title('Final line extraction')
plt.axis('off')
plt.show()

figure(figsize = (12, 12), dpi = 120);
imshow(final_data, cmap='gray',  vmin = 0, vmax = 1)
plt.title('Final data-only extraction')
plt.axis('off')
plt.show()

figure(figsize = (12, 12), dpi = 120);
imshow(final_extracted_corners, cmap='gray',  vmin = 0, vmax = 1)
plt.title('Box corner extraction')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Fine extraction of box corners

# %%
def find_box_corners(img, gap_radius=30):

    white_pixels = np.argwhere(img)

    corners = []
    stored_x = []
    stored_y = []

    for pix in white_pixels:
        x = pix[0]
        y = pix[1]

        if not stored_x and not stored_y:
            stored_x.append(x)
            stored_y.append(y)
            corners.append([x, y])

        else:

            cnt = 0
            for el_x, el_y in zip(stored_x, stored_y):
                if abs(x-el_x)>gap_radius or abs(y-el_y)>gap_radius:
                    cnt += 1

            if cnt == len(stored_x):
                stored_x.append(x)
                stored_y.append(y)
                corners.append([x, y])

    return np.array(corners).reshape((len(corners), 2))
  
box_corners = find_box_corners(final_extracted_corners)
num_box_corners = box_corners.shape[0]

print('Number of detected horizontal lines: ' + str(num_horizontals))
print('Number of detected vertical lines: ' + str(num_verticals))
print('Expected number of box corners to be detected: ' + str(num_verticals*num_horizontals))
print('Number of detected box corners: ' + str(num_box_corners))

if num_verticals*num_horizontals == num_box_corners:
    print('Expected number of fields/boxes: ' + str((num_verticals-1)*(num_horizontals-1)))
    print('Expected number of table rows: ' + str(num_horizontals-1))
    print('Expected number of table colums: ' + str(num_verticals-1))

    num_boxes = num_box_corners
    num_table_rows = num_horizontals-1
    num_table_cols = num_horizontals-1
else:
    print('Number of detected box corners missmatch expected number of box corners to be detected!')
# Out:
# Number of detected horizontal lines: 6
# Number of detected vertical lines: 6
# Expected number of box corners to be detected: 36
# Number of detected box corners: 36
# Expected number of fields/boxes: 25
# Expected number of table rows: 5
# Expected number of table colums: 5

# %%
def sort_corners(box_corners, num_table_rows, num_table_cols, gap_radius=50):
  
    left_corners = list(np.squeeze(box_corners[np.argwhere(box_corners[:,1]<100)]))

    box_corners_list = []

    for corner in box_corners:
        x = corner[0]
        y = corner[1]
        box_corners_list.append([x, y])

    sorted_corners = []

    for row in range(num_table_rows+1):

        row_corners = []
        corner = list(left_corners[row])
        row_corners.append(corner)

        box_corners_list.remove(corner)
        box_corners = np.array(box_corners_list)

        for col in range(num_table_cols):
            corners_on_right = np.squeeze(box_corners[np.argwhere(abs(box_corners[:,0]-corner[0])<gap_radius)])
            if col < num_table_cols-1:
                corners_on_right = np.squeeze(corners_on_right[np.argwhere(abs(corners_on_right[:,1]-corner[1])>gap_radius)])
                corner_on_right = np.squeeze(corners_on_right[np.argmin(corners_on_right[:,1])])
            else:
                corner_on_right = np.squeeze(corners_on_right)

            corner = list(corner_on_right)

            box_corners_list.remove(corner)
            box_corners = np.array(box_corners_list)

            row_corners.append(corner)

        sorted_corners.append(row_corners)

    return sorted_corners

def get_boxes(img, sorted_corners, num_table_rows, num_table_cols):

    fig, axes = plt.subplots(nrows=num_table_rows, ncols=num_table_cols, figsize=(20,8), dpi=120)
    ax = axes.ravel()

    fields_dict = {}

    for row in range(num_table_rows):
        for col in range(num_table_cols):
            x0, y0 = sorted_corners[row][col]
            x1, y1 = sorted_corners[row][col+1]
            x2, y2 = sorted_corners[row+1][col]
            x3, y3 = sorted_corners[row+1][col+1]

            field = img[min(x0, x1):max(x2, x3), min(y0, y2):max(y1, y3)]
            field_name = 'row_' + str(row) + '_col_' + str(col) 

            io.imsave('extracted_fields/' + img_name + '/' + field_name + '.jpg', uint8(255*(1-field)))

            ax[row*num_table_cols+col].imshow(field, cmap='gray', vmin=0, vmax=1)
            ax[row*num_table_cols+col].set_title('Field: ' + field_name)
            ax[row*num_table_cols+col].set_axis_off()

sorted_corners = sort_corners(box_corners, num_table_rows, num_table_cols)
get_boxes(final_data, sorted_corners, num_table_rows, num_table_cols)
# Out:
# <ipython-input-11-13950d53f3a9>:59: UserWarning: extracted_fields/serbian_latin/row_0_col_0.jpg is a low contrast image
#   io.imsave('extracted_fields/' + img_name + '/' + field_name + '.jpg', uint8(255*(1-field)))
# <ipython-input-11-13950d53f3a9>:59: UserWarning: extracted_fields/serbian_latin/row_1_col_2.jpg is a low contrast image
#   io.imsave('extracted_fields/' + img_name + '/' + field_name + '.jpg', uint8(255*(1-field)))
# <ipython-input-11-13950d53f3a9>:59: UserWarning: extracted_fields/serbian_latin/row_2_col_3.jpg is a low contrast image
#   io.imsave('extracted_fields/' + img_name + '/' + field_name + '.jpg', uint8(255*(1-field)))

# %% [markdown]
# ## PyTesseract - OCR/Data extraction from extracted boxes

# %%
def clean_extracted_string(string):
    cleaned_string = string.replace('\n', '')
    cleaned_string = cleaned_string.replace('\t', '')
    cleaned_string = cleaned_string.replace('-', '')
    cleaned_string = cleaned_string.strip()
    
    return cleaned_string

def clean_extracted_data_string(data_string):
    
    if data_string == '':
        cleaned_data = np.nan
    
    cleaned_data = ''
    for word in data_string.split():
        if word.isdigit():
            cleaned_data += word
      
    if cleaned_data == '':
        cleaned_data = np.nan
    
    return float(cleaned_data)

try:
    from PIL import Image
except ImportError:
    import Image
    
extracted_row_names = []
extracted_column_names = []

for row in range(num_table_rows):
    row_name = pytesseract.image_to_string(Image.open('extracted_fields/'+img_name+'/row_'+str(row)+'_col_0.jpg'), lang=tesseract_langs[img_name], config='--psm 6')
    row_name = clean_extracted_string(row_name)
    extracted_row_names.append(row_name)
    
for col in range(num_table_cols):
    column_name = pytesseract.image_to_string(Image.open('extracted_fields/'+img_name+'/row_0_col_'+str(col)+'.jpg'), lang=tesseract_langs[img_name], config='--psm 6')
    column_name = clean_extracted_string(column_name)
    extracted_column_names.append(column_name)

df = pd.DataFrame(np.nan*np.ones((len(extracted_row_names[1:]), len(extracted_column_names[1:]))))
df.columns = extracted_column_names[1:]
df.index = extracted_row_names[1:]
df.index.name = extracted_column_names[0]

for row in range(1,num_table_rows):
    for col in range(1,num_table_cols):
        data = pytesseract.image_to_string(Image.open('extracted_fields/'+img_name+'/row_'+str(row)+'_col_'+str(col)+'.jpg'), lang=tesseract_langs[img_name], config='--psm 6')
        data = clean_extracted_string(data)
        data = clean_extracted_data_string(data)
        
        df.at[extracted_row_names[row], extracted_column_names[col]] = data
        
df.to_csv('results/' + img_name + '/table.csv')

print('Results: \n')
df
# Out:
# Results:
#                     · centralna zona  _ bliža periferija  dalja periferija  \
#
# · centralna zona                25.0                 NaN               NaN
# · bliža periferija              34.0                19.0               NaN
# dalja periferija                 8.0                 4.0               NaN
# Ukupno                          66.0                 0.0               3.0
#
#                     Ukupno
#
# · centralna zona      33.0
# · bliža periferija     4.0
# dalja periferija      13.0
# Ukupno               100.0

# %% [markdown]
# ## Accuracy
#
# Strings on table image containing only letters are almost perfectly extracted. So let's measure accuracy of extraction of this table data.

# %%
table_data = np.array([[25.0, 7.0, 1.0, 33.0],
                       [34.0, 19.0, 1.0, 54.0],
                       [8.0, 4.0, 1.0, 13.0],
                       [66.0, 30.0, 3.0, 100.0]])

table_size = table_data.shape[0] * table_data.shape[1]

cnt = 0
for row in range(1,num_table_rows):
    for col in range(1,num_table_cols):
        if df.loc[extracted_row_names[row], extracted_column_names[col]] == table_data[row-1, col-1]:
            cnt += 1
            
acc = 100*cnt/table_size
print('Accuracy : {:.2f}%'.format(acc))
# Out:
# Accuracy : 62.50%
